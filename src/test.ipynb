# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('../results/length50/scaled_mean_contour.csv')
infected = data1['scaled_mean'].to_numpy()
p1 = data1['p1'].to_numpy()
p3 = data1['p3'].to_numpy()

contour_plot2 = infected[p1==1]
for p in np.flip(np.unique(p1))[1:]:
    contour_plot2 = np.vstack((contour_plot2, infected[p1==p]))

# %%
sns.set_theme()
plt.figure(figsize=(10,8))
plt.contourf(contour_plot2, cmap='magma', extent=[0, 1, 0, 1], origin='upper')
plt.xlabel('p3')
plt.ylabel('p1')

plt.colorbar()
plt.show()
# Out:
# /var/folders/vp/xzr11zg50cgd4l7fb1g7lwf40000gn/T/ipykernel_69289/1318107939.py:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
data2 = pd.read_csv('../results/length50/scaled_var_contour.csv')
infected = data2['scaled_var'].to_numpy()
p1 = data2['p1'].to_numpy()
p3 = data2['p3'].to_numpy()

contour_plot1 = infected[p1==1]
for p in np.flip(np.unique(p1))[1:]:
    contour_plot1 = np.vstack((contour_plot1, infected[p1==p]))

# %%
sns.set_style("dark")
plt.figure(figsize=(10,8))
plt.imshow(contour_plot1, cmap='magma', extent=[0, 1, 0, 1], interpolation=None)
plt.xlabel('p3')
plt.ylabel('p1')
plt.colorbar()

# %%
data3 = pd.read_csv('../results/length50/scaled_variance2.csv')
x_data3 = data3['p1']
y_data3 = data3['scaled_var']
yerr3 = data3['error_bars']

# %%
sns.set_theme()
plt.figure(figsize=(10,8))
plt.errorbar(x_data3, y_data3, yerr3, ecolor='orange', capsize=3)
plt.xlabel('Probability p1')
plt.ylabel('Scaled variance')
# Out:
# Text(0, 0.5, 'Scaled variance')

# %%
data4 = pd.read_csv('../results/length50/immunity_data_0.01.csv')
x_data4 = data4['immune_frac']
y_data4 = data4['avg_frac_infected']
yerr4 = data4['std_error_mean']

# %%
plt.figure(figsize=(10,8))
# plt.scatter(x_data4, y_data4)
plt.errorbar(x_data4, y_data4, yerr4, capsize=2, ecolor="black")
plt.xlabel('Immune fraction')
plt.ylabel('Avg fraction of infected sites')
# Out:
# Text(0, 0.5, 'Avg fraction of infected sites')
